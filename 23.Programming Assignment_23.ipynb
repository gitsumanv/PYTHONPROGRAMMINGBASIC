# %% [markdown]
# # Assignment 23 Solutions

# %% [markdown]
# #### 1.Create a function that takes a number as an argument and returns True or False depending on whether the number is symmetrical or not. A number is symmetrical when it is the same as its reverse.
# **Examples:**
# `is_symmetrical(7227) ➞ True`
# `is_symmetrical(12567) ➞ False`
# `is_symmetrical(44444444) ➞ True`
# `is_symmetrical(9939) ➞ False`
# `is_symmetrical(1112111) ➞ True`

# %%
def is_symmetrical(input_num):
  if str(input_num)==str(input_num)[::-1]:
    print(f'{input_num}--> {True}')
  else:
    print(f'{input_num}-->{False}')
is_symmetrical(7227)
is_symmetrical(12567)
is_symmetrical(44444444)
is_symmetrical(9939)
is_symmetrical(1112111)
# Out:
# 7227--> True
# 12567-->False
# 44444444--> True
# 9939-->False
# 1112111--> True

# %% [markdown]
# #### 2.Given a string of numbers separated by a comma and space, return the product of the numbers.
# **Examples:**
# `multiply_nums("2, 3") ➞ 6`
# `multiply_nums("1, 2, 3, 4") ➞ 24`
# `multiply_nums("54, 75, 453, 0") ➞ 0`
# `multiply_nums("10, -2") ➞ -20`

# %%
def multiply_nums():
  input_str=input('enter a string of nums').split(",")
  mul=1
  for i in input_str:
    mul=mul*int(i)
  return mul

print(f'{multiply_nums()}')
print(f'{multiply_nums()}')
print(f'{multiply_nums()}')
print(f'{multiply_nums()}')
# Out:
# enter a string of nums2,3
# 6
# enter a string of nums1,2,3,4
# 24
# enter a string of nums54,75,453,0
# 0
# enter a string of nums10,-2
# -20

# %% [markdown]
# #### 3.Create a function that squares every digit of a number.
# **Examples:**
# `square_digits(9119) ➞ 811181`
# `square_digits(2483) ➞ 416649`
# `square_digits(3212) ➞ 9414`
#
# **Notes:**
# The function receives an integer and must return an integer.

# %%
def square_digits(num):
    in_list = [str(int(ele)**2) for ele in str(num)]
    out_list = ''.join(in_list)
    print(f'{num} ➞ {int(out_list)}')

square_digits(9119)
square_digits(2483)
square_digits(3212)
# Out:
# 9119 ➞ 811181
# 2483 ➞ 416649
# 3212 ➞ 9414

# %% [markdown]
# #### 4.Create a function that sorts a list and removes all duplicate items from it.
# **Examples:**
# `setify([1, 3, 3, 5, 5]) ➞ [1, 3, 5]`
# `setify([4, 4, 4, 4]) ➞ [4]`
# `setify([5, 7, 8, 9, 10, 15]) ➞ [5, 7, 8, 9, 10, 15]`
# `setify([3, 3, 3, 2, 1]) ➞ [1, 2, 3]`

# %%
def setsort(input_list):
  output_list=sorted(set(input_list))
  return output_list
print(f'{setsort([1, 3, 3, 5, 5])}')
print(f'{setsort([4, 4, 4, 4])}')
print(f'{setsort([5, 7, 8, 9, 10, 15])}')
print(f'{setsort([3, 3, 3, 2, 1])}')
# Out:
# [1, 3, 5]
# [4]
# [5, 7, 8, 9, 10, 15]
# [1, 2, 3]

# %% [markdown]
# #### 5.Create a function that returns the mean of all digits.
# **Examples:**
# `mean(42) ➞ 3`
# `mean(12345) ➞ 3`
# `mean(666) ➞ 6`
#
# **Notes:**
#     1.The mean of all digits is the sum of digits / how many digits there are (e.g. mean of digits in 512 is (5+1+2)/3(number of digits) = 8/3=2).
#     2.The mean will always be an integer.

# %%
def find_mean(num):
  count=0
  sum=0
  while(num>0):
    sum=sum+(num%10)
    count=count+1
    num=num//10
  return sum/count
find_mean(num=512)
# Out:
# 2.6666666666666665
