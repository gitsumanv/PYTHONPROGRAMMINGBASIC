# %% [markdown]
# # Assignment 7 Solutions

# %% [markdown]
# #### 1. Write a Python Program to find sum of Array ?

# %%
def arraySum():
    arr=[1,2,3,4,5]
    sumofarray=sum(arr)
    print(sumofarray)

arraySum()
# Out:
# 15

# %% [markdown]
# #### 2. Write a Python Program to find Largest element in an Array ?

# %%
arr=input('enter space separtated elements;').split()
def largeElement():
    print(f'the largest element is {arr} is {sorted(arr,reverse=True)[0]}')
largeElement()
# Out:
# enter space separtated elements;1 2 3 4 5
# the largest element is ['1', '2', '3', '4', '5'] is 5

# %% [markdown]
# #### 3. Write a Python Program for array rotation ?

# %%
arr=input('enter space separtated elements;').split()
def reverseArray():
  print(f'the reverse of array {arr} is {arr[::-1]}')
reverseArray()
# Out:
# enter space separtated elements;1 2 3 4 5 6
# the reverse of array ['1', '2', '3', '4', '5', '6'] is ['6', '5', '4', '3', '2', '1']

# %% [markdown]
# #### 4. Write a Python Program to Split the array and add the first part to the end ?

# %%
def splitArr(a,n,k):
  b=a[:k]
  return (a[k::]+b[::])
arr=[12,10,5,6,52,36]
n=len(arr)
k=1
arr=splitArr(arr,n,position)

for i in range(0,n):
  print(arr[i],end='')
# Out:
# 5652361210

# %% [markdown]
# #### 5. Write a Python Program to check if given array is Monotonic ?

# %%
def check(arr):
    n=len(arr)
    inc=True
    dec=True
    for i in range(0,n-1):
        if arr[i] >arr[i+1]:
            inc=False
    for i in range(0,n-1):
        if arr[i]<arr[i+1]:
            dec=False
    return inc or dec

arr=[1,2,3,4]
answer=check(arr)
if check(arr)==True:
    print('yes')
else:
    print('no')
# Out:
# yes
