# %% [markdown]
# # Assignment 17 Solutions

# %% [markdown]
# #### 1.Create a function that takes three arguments a, b, c and returns the sum of the numbers that are evenly divided by c from the range a, b inclusive ?
# **Examples:**
# `evenly_divisible(1, 10, 20) ➞ 0
#     # No number between 1 and 10 can be evenly divided by 20.
# evenly_divisible(1, 10, 2) ➞ 30
#     # 2 + 4 + 6 + 8 + 10 = 30
# evenly_divisible(1, 10, 3) ➞ 18
#     # 3 + 6 + 9 = 18`

# %%
def evenDivide(a,b,c):
  List=[]
  for i in range(a,b+1):
    if i%c==0:
      List.append(i)
  print(f'{a,b,c} -->{sum(List)}')
evenDivide(1,10,20)
evenDivide(1,10,2)
evenDivide(1,10,3)
# Out:
# (1, 10, 20) -->0
# (1, 10, 2) -->30
# (1, 10, 3) -->18

# %% [markdown]
# #### 2.Create a function that returns True if a given inequality expression is correct and False otherwise ?
# **Examples:**
# `correct_signs("3 < 7 < 11") ➞ True`
# `correct_signs("13 > 44 > 33 > 1") ➞ False`
# `correct_signs("1 < 2 < 6 < 9 > 3") ➞ True`

# %%
def checkexpression():
  input_str=input('enter the inequality ')
  output=eval(input_str)
  print(f'{input_str}--> {output}')
checkexpression()
checkexpression()
checkexpression()
# Out:
# enter the inequality 3 < 7 < 11
# 3 < 7 < 11--> True
# enter the inequality 13 > 44 > 33 > 1
# 13 > 44 > 33 > 1--> False
# enter the inequality 1 < 2 < 6 < 9 > 3
# 1 < 2 < 6 < 9 > 3--> True

# %% [markdown]
# #### 3.Create a function that replaces all the vowels in a string with a specified character ?
# **Examples:**
# `replace_vowels("the aardvark", "#") ➞ "th# ##rdv#rk"`
# `replace_vowels("minnie mouse", "?") ➞ "m?nn?? m??s?"`
# `replace_vowels("shakespeare", "*") ➞ "shksp**r"`

# %%
def replacevowels():
  input_str=input('enter  ta string')
  vowels=['a','e','i','o','u','A','E','I','O','U']
  output=input_str
  replace_with=input('enter a character to be placed')
  for i in input_str:
    if i in vowels:
      output=input_str.replace(i,replace_with)
  print(output)
replacevowels()
replacevowels()
replacevowels()
# Out:
# enter  ta stringthe aardvark
# enter a character to be placed#
# the ##rdv#rk
# enter  ta stringminnie mouse
# enter a character to be placed?
# minni? mous?
# enter  ta stringshakespeare
# enter a character to be placed *
# shak *sp *ar *

# %% [markdown]
# #### 4.Write a function that calculates the factorial of a number recursively ?
# **Examples:**
# `factorial(5) ➞ 120`
# `factorial(3) ➞ 6`
# `factorial(1) ➞ 1`
# `factorial(0) ➞ 1`

# %%
def factorial(n):
    if n==0 or n==1:
        return 1
    else:
       return n * factorial(n-1)

print(f'factorial(5) ➞ {factorial(5)}')
print(f'factorial(3) ➞ {factorial(3)}')
print(f'factorial(1) ➞ {factorial(1)}')
print(f'factorial(0) ➞ {factorial(0)}')
# Out:
# factorial(5) ➞ 120
# factorial(3) ➞ 6
# factorial(1) ➞ 1
# factorial(0) ➞ 1

# %% [markdown]
# #### 5.Hamming distance is the number of characters that differ between two strings ?
# To illustrate:
#     `String1: "abcbba"`
#     `String2: "abcbda"`
# Hamming Distance: 1 - "b" vs. "d" is the only difference.
# Create a function that computes the hamming distance between two strings.
# **Examples:**
# `hamming_distance("abcde", "bcdef") ➞ 5`
# `hamming_distance("abcde", "abcde") ➞ 0`
# `hamming_distance("strong", "strung") ➞ 1`

# %%
def getDist():
  str1=input('string 1 enter ')
  str2=input('string  2 enter ')

  max_len=max(len(str1),len(str2))

  count=0
  for i in range(max_len):
    if str1[i]!=str2[i]:
      count=count+1
  print(count)
getDist()
getDist()
getDist()
# Out:
# string 1 enter abcde
# string  2 enter bcdef
# 5
# string 1 enter abcde
# string  2 enter abcde
# 0
# string 1 enter strong
# string  2 enter strung
# 1
