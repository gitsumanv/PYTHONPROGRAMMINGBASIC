# %% [markdown]
# # Assignment 11 Solutions

# %% [markdown]
# #### 1. Write a Python program to find words which are greater than given length k ?

# %%
def checkLengthOfString():
    in_string = input("Enter the string: ")
    in_length = int(input('Enter the length of the string: '))
    out_string = []
    for string in in_string.split(" "):
        if len(string) > in_length:
            out_string.append(string)
    print(','.join(out_string))

checkLengthOfString()
# Out:
# Enter the string: i love playing cricket
# Enter the length of the string: 2
# love,playing,cricket

# %%
def checkLength():
  input_str=input('enter the  string:')
  greater_length=int(input('enter the length of string'))
  output_string=[]
  for string in input_str.split(" "):
    if len(string)>greater_length:
      output_string.append(string)
  print(','.join(output_string))
checkLength()
# Out:
# enter the  string:i love playing cricket
# enter the length of string3
# love,playing,cricket

# %% [markdown]
# #### 2. Write a Python program for removing i-th character from a string ?

# %%
def removeCharacter():
    in_string = input("Enter the String: ")
    in_char_num = int(input("Enter the ith Character: "))
    out_string = ''
    for ele in range(len(in_string)):
        if ele != in_char_num:
            out_string = out_string + in_string[ele]
    print(out_string)

removeCharacter()
# Out:
# Enter the String: ineuron
# Enter the ith Character: 2
# inuron

# %%
def remove(string,i):
  a=string[:i]
  b=string[i+1:]
  return a+b
string='doingcodeisfun'
i=input('enter ith charcter you want to remove')
remove(string,4)
# Out:
# enter ith charcter you want to remove5
# 'doincodeisfun'

# %% [markdown]
# #### 3. Write a Python program to split and join a string ?

# %%
def splitJoinString():
    in_string = input('Enter the string: ')
    print(f"Split String: {in_string.split(' ')}")
    print(f"Join String: {' '.join(in_string.split(' '))}")

splitJoinString()
# Out:
# Enter the string: after dark mr kitty
# Split String: ['after', 'dark', 'mr', 'kitty']
# Join String: after dark mr kitty

# %% [markdown]
# #### 4. Write a Python to check if a given string is binary string or not ?

# %%
string =input('enter the string')
if(string.count('0')+string.count('1')==len(string)):
	print("Yes")
else:
	print("No")
# Out:
# enter the string12001
# No

# %% [markdown]
# #### 5. Write a Python program to find uncommon words from two Strings ?

# %%
def unCommonWords():
    in_string_1 = set(input("Enter the String 1: ").split(' '))
    in_string_2 = set(input("Enter the String 2: ").split(' '))
    out_string = (in_string_1.union(in_string_2)).difference(in_string_1.intersection(in_string_2))
    print(out_string)

unCommonWords()
# Out:
# Enter the String 1: Supervised Learning
# Enter the String 2: Unsupervised Learning
# {'Unsupervised', 'Supervised'}

# %% [markdown]
# #### 6. Write a Python to find all duplicate characters in string ?

# %%
def duplicateChars():
  input_str=input('enter  the string: ')
  duplicates=[]
  non_duplicates=[]
  for i in input_str:
    if i not in non_duplicates:
      non_duplicates.append(i)
    else:
      duplicates.append(i)
  print(f'Duplicate characters are:{list(set(duplicates))}')
duplicateChars()
# Out:
# enter  the string: fantastic yes
# Duplicate characters are:['s', 't', 'a']

# %% [markdown]
# #### 7. Write a Python Program to check if a string contains any special character?

# %%
def checkspecialchar():
    spl_chars= '[@_!#$%^&*()<>?/\|}{~:]'
    input_str=input('enter the string')
    count=0
    char_list=[]
    for i in input_str:
        if i in spl_chars:
            char_list.append(i)
            count=count+1
    print(f"there are {count} special characters in input str which are {char_list}")
checkspecialchar()
# Out:
# enter the stringwond()*#$@
# there are 6 special characters in input str which are ['(', ')', '*', '#', '$', '@']
