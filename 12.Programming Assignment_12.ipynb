# %% [markdown]
# # Assignment 12 Solutions

# %% [markdown]
# #### 1.Write a Python program to Extract Unique values dictionary values?

# %%
input_dict = {1:'Aravali',2:'Nilgiri',3:'Udaigiri',4:'Shivalik',5:'Nilgiri',6:'Udaigiri'}

print(input_dict.values())
print(set(input_dict.values()))
# Out:
# dict_values(['Aravali', 'Nilgiri', 'Udaigiri', 'Shivalik', 'Nilgiri', 'Udaigiri'])
# {'Nilgiri', 'Shivalik', 'Aravali', 'Udaigiri'}

# %% [markdown]
# #### 2.Write a Python program to find the sum of all items in a dictionary?

# %%
input_dict = {'Nokia':10000,'Xiomi':20000,'Pixel':30000,'Nothing':40000,'Apple':50000}
print('sum of the items of input_dict is', sum(input_dict.values()))
# Out:
# sum of the items of input_dict is 150000

# %% [markdown]
# #### 3.Write a Python program to Merging two Dictionaries?

# %%
phone_details = {
    'phone_name':'pixel'
}
specs= {
    'specifications':['tensor','goodcamer']
}
phone_details.update(specs)
print(phone_details)
# Out:
# {'phone_name': 'pixel', 'specifications': ['tensor', 'goodcamer']}

# %% [markdown]
# #### 4.Write a Python program to convert key-values list to flat dictionary?

# %%
in_list = [('A',10),('B',20),('C',30),('D',40),('E',50),('F',60),('G',70),('H',80),('I',90),('J',100)]


dict(in_list)
# Out:
# {'A': 10,
#  'B': 20,
#  'C': 30,
#  'D': 40,
#  'E': 50,
#  'F': 60,
#  'G': 70,
#  'H': 80,
#  'I': 90,
#  'J': 100}

# %% [markdown]
# #### 5.Write a Python program to insertion at the beginning in OrderedDict?

# %%
from collections import OrderedDict

diction=OrderedDict({'Nothing':'nothing','Google':'Pixel','Apple':'iphone'})
dict_two={'Moto':'edge'}
dict_two.update(diction)
diction=dict_two
diction
# Out:
# {'Moto': 'edge', 'Nothing': 'nothing', 'Google': 'Pixel', 'Apple': 'iphone'}

# %% [markdown]
# #### 6.Write a Python program to check order of character in string using OrderedDict()?

# %%
from collections import OrderedDict
first_list={'a':'1000','d':'200','c':'500','f':'250'}
print(first_list)
final_list=OrderedDict(dict(sorted(first_list.items())))
print(final_list)
# Out:
# {'a': '1000', 'd': '200', 'c': '500', 'f': '250'}
# OrderedDict([('a', '1000'), ('c', '500'), ('d', '200'), ('f', '250')])

# %% [markdown]
# #### 7.Write a Python program to sort Python Dictionaries by Key or Value?

# %%
d_items = {'Mango':100,'PineApple':22,'Banana':60,'Grape':13}

def sort_dict(in_dict,sort_type):
    if sort_type == 'key':
        print(dict(sorted(in_dict.items(), key=lambda x:x[0], reverse=False)))
    else:
        print(dict(sorted(in_dict.items(), key=lambda x:x[1], reverse=False)))

sort_dict(d_items,'key')
sort_dict(d_items,'value')
# Out:
# {'Banana': 60, 'Grape': 13, 'Mango': 100, 'PineApple': 22}
# {'Grape': 13, 'PineApple': 22, 'Banana': 60, 'Mango': 100}
